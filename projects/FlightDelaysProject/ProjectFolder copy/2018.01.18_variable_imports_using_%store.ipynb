# %% [markdown]
# ## 2018.01.18_variable imports using %store

# %%
# %store -r data
# %store -r col_year_month
# %store -r col_categorical
# %store -r col_target
# %store -r col_numeric
# %store -r combined_list

# %%
# %store -r Denver_grouping

# %%
combined_list
# Out:
# ['year',
#  'month',
#  'carrier',
#  'airport',
#  'arr_flights',
#  'carrier_ct',
#  'weather_ct',
#  'nas_ct',
#  'security_ct',
#  'late_aircraft_ct',
#  'arr_cancelled',
#  'arr_diverted',
#  'arr_delay',
#  'carrier_delay',
#  'weather_delay',
#  'nas_delay',
#  'security_delay',
#  'late_aircraft_delay',
#  'target']

# %%
data.head()
# Out:
#    year  month carrier            carrier_name airport  \
# 0  2016      1      AA  American Airlines Inc.     DFW
# 1  2016      1      AA  American Airlines Inc.     DTW
# 2  2016      1      AA  American Airlines Inc.     SEA
# 3  2016      1      AA  American Airlines Inc.     JFK
# 4  2016      1      AA  American Airlines Inc.     SJC
#
#                                         airport_name  arr_flights  carrier_ct  \
# 0  Dallas/Fort Worth, TX: Dallas/Fort Worth Inter...      11956.0      507.33
# 1            Detroit, MI: Detroit Metro Wayne County        588.0       34.71
# 2          Seattle, WA: Seattle/Tacoma International        607.0       35.52
# 3        New York, NY: John F. Kennedy International       1595.0      117.00
# 4  San Jose, CA: Norman Y. Mineta San Jose Intern...        327.0       23.67
#
#    weather_ct  nas_ct   ...    late_aircraft_ct  arr_cancelled  arr_diverted  \
# 0       39.83  452.65   ...              529.47          201.0           9.0
# ...

# %%
carrier_group = data.groupby(by=['carrier', 'airport'])
# carrier_group.arr_flights.sum()
# carrier  airport
# AA       ABQ          1613.0
#          ALB           933.0
#          AMA           103.0
#          ANC           443.0
#          ATL         10846.0
#          AUS          8591.0

# %%
flights_group = data.iloc[:, 1:].groupby(by=['airport','carrier','target', 'month'])
flights_group.sum()
# Out:
#                               arr_flights  carrier_ct  weather_ct  nas_ct  \
# airport carrier target month
# ABE     DL      0      1             28.0        0.41        0.29    1.82
#                        2             29.0        2.28        0.06    0.66
#                        3             30.0        1.00        1.22    1.00
#                        4             30.0        0.75        0.00    1.00
#                        5             31.0        0.65        0.06    0.69
#                        6             30.0        1.18        1.00    1.70
#                        7             32.0        3.09        2.60    1.11
#                        8             31.0        1.00        0.00    0.00
#                        9             32.0        1.00        1.00    0.00
#                        10            33.0        0.00        0.00    0.00
#                        11            30.0        1.00        0.00    0.00
# ...

# %%
# data.arr_flights

# %%
Denver_grouping.sum()
# Out:
#                  carrier_ct  target
# airport carrier
# DEN     AA           718.90      11
#         AS            71.55       6
#         B6            93.23       9
#         DL           427.88      11
#         F9           763.01      11
#         NK           124.74      11
#         OO          1414.07      11
#         UA          2077.87      11
#         VX            23.79       5
#         WN          2469.61      11
