# %%
import numpy as np
import pandas as pd

# %%
airline_delay_causes_data = pd.read_csv('682464398_102017_1651_airline_delay_causes.csv')
airline_delay_causes_data.shape
# Out:
# (11193, 22)

# %%
airline_delay_causes_data.sample(8)
# Out:
#        year   month carrier              carrier_name airport  \
# 8183   2016       9      AA    American Airlines Inc.     ORF
# 8164   2016       9      AA    American Airlines Inc.     LAX
# 10114  2016      10      WN    Southwest Airlines Co.     CMH
# 10550  2016      11      EV  ExpressJet Airlines Inc.     PNS
# 7450   2016       8      DL      Delta Air Lines Inc.     DLH
# 2601   2016       3      NK          Spirit Air Lines     DTW
# 1782   2016       2      OO     SkyWest Airlines Inc.     EAU
# 7854   2016       8      OO     SkyWest Airlines Inc.     PNS
#
#                                           airport_name  arr_flights  \
# 8183                Norfolk, VA: Norfolk International        129.0
# 8164        Los Angeles, CA: Los Angeles International       3204.0
# 10114  Columbus, OH: John Glenn Columbus International        937.0
# 10550           Pensacola, FL: Pensacola International        157.0
# ...

# %%
airline_delay_causes_data.year.value_counts()
# Out:
# 2016    11193
# Name: year, dtype: int64
