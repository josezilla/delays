# %%
import numpy as np
import pandas as pd

# %%
on_time_data = pd.read_csv('682271467_T_ONTIME.csv')
on_time_data.shape
# Out:
# (37731, 8)

# %%
on_time_data.sample(10)
# Out:
#        ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID ORIGIN  \
# 9559               11292                1129202                  30325    DEN
# 8236               11292                1129202                  30325    DEN
# 37077              15016                1501603                  31123    STL
# 16504              11292                1129202                  30325    DEN
# 11861              11292                1129202                  30325    DEN
# 21586              11298                1129803                  30194    DFW
# 23151              11540                1154003                  30615    ELP
# 25910              12266                1226603                  31453    IAH
# 18665              11292                1129202                  30325    DEN
# 31200              13871                1387102                  33316    OMA
#
#        DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID  DEST_CITY_MARKET_ID  Unnamed: 7
# ...
