# %% [markdown]
# # DAT-DEN-03 | Lesson 10

# %%
import os
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
from sklearn import linear_model, metrics
from sklearn import grid_search, cross_validation
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.cross_validation import train_test_split
from sklearn import metrics 
from sklearn.metrics import roc_curve, roc_auc_score

pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

# %matplotlib inline
plt.style.use('ggplot')

# %%
feature_set1 = df[['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']]
X_train, X_test, y_train, y_test = train_test_split(feature_set, ys.Setosa, test_size = .3)

# %%
# Read iris.csv as df
df = pd.read_csv(os.path.join('..', 'datasets', 'iris.csv'))
X = df[['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']]

ys = pd.get_dummies(df.Species, prefix = None)
y_true_Setosa = ys.Setosa
y_true_Versicolor = ys.Versicolor
y_true_Virginica = ys.Virginica

# %% [markdown]
# ## Get dummies and create three separate logistic regression.
# For each model:
# - cross validate and use grid search to find the optimum values (start with scoring='roc_auc')
# - print and plot confusion matrix
# - plot ROC
# - Print AUC
#
# Then change your scoring to recall or precision.. What do you notice?

# %% [markdown]
# ## Model Setosa

# %%
y = df.Species

# %%
gs = grid_search.GridSearchCV(
    estimator=LogisticRegression(),
    param_grid= {'C': [10**-i for i in range(-5, 5)], 'class_weight': [None, 'balanced']},
    cv=cross_validation.KFold(n=len(X_train), n_folds=10),
    scoring='roc_auc'
)
gs.fit(X_train, y_train)
gs.grid_scores_
# Out:
# [mean: 1.00000, std: 0.00000, params: {'C': 100000, 'class_weight': None},
#  mean: 1.00000, std: 0.00000, params: {'C': 100000, 'class_weight': 'balanced'},
#  mean: 1.00000, std: 0.00000, params: {'C': 10000, 'class_weight': None},
#  mean: 1.00000, std: 0.00000, params: {'C': 10000, 'class_weight': 'balanced'},
#  mean: 1.00000, std: 0.00000, params: {'C': 1000, 'class_weight': None},
#  mean: 1.00000, std: 0.00000, params: {'C': 1000, 'class_weight': 'balanced'},
#  mean: 1.00000, std: 0.00000, params: {'C': 100, 'class_weight': None},
#  mean: 1.00000, std: 0.00000, params: {'C': 100, 'class_weight': 'balanced'},
#  mean: 1.00000, std: 0.00000, params: {'C': 10, 'class_weight': None},
#  mean: 1.00000, std: 0.00000, params: {'C': 10, 'class_weight': 'balanced'},
#  mean: 1.00000, std: 0.00000, params: {'C': 1, 'class_weight': None},
#  mean: 1.00000, std: 0.00000, params: {'C': 1, 'class_weight': 'balanced'},
#  mean: 1.00000, std: 0.00000, params: {'C': 0.1, 'class_weight': None},
#  mean: 1.00000, std: 0.00000, params: {'C': 0.1, 'class_weight': 'balanced'},
#  mean: 1.00000, std: 0.00000, params: {'C': 0.01, 'class_weight': None},
#  mean: 1.00000, std: 0.00000, params: {'C': 0.01, 'class_weight': 'balanced'},
#  mean: 1.00000, std: 0.00000, params: {'C': 0.001, 'class_weight': None},
#  mean: 1.00000, std: 0.00000, params: {'C': 0.001, 'class_weight': 'balanced'},
#  mean: 1.00000, std: 0.00000, params: {'C': 0.0001, 'class_weight': None},
#  mean: 1.00000, std: 0.00000, params: {'C': 0.0001, 'class_weight': 'balanced'}]

# %%
y_pred = gs.best_estimator_.predict(X_test)
confusion_matrix = confusion_matrix(y_test, y_pred)
confusion_matrix
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-f3039ee4e308> in <module>()
#       1 y_pred = gs.best_estimator_.predict(X_test)
# ----> 2 confusion_matrix = confusion_matrix(y_test, y_pred)
#       3 confusion_matrix
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
plt.matshow(confusion_matrix)
plt.title('Confusion matrix')
plt.colorbar()
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show()

# %%
y_pro = gs.best_estimator_.predict_proba(X_test)
fpr = roc_curve(y_test, y_pred)[0]
tpr = roc_curve(y_test, y_pred)[1]
plt.plot(fpr, tpr)

# %%
roc_auc_score(y_test, y_pred)
# Out:
# 1.0

# %%
y_pro = gs.best_estimator_.predict_proba(X_test)
fpr = roc_curve(y_test, y_pro[:,1])[0]
tpr = roc_curve(y_test, y_pro[:,1])[1]
plt.plot(fpr, tpr)

# %% [markdown]
# ## Model Versicilor

# %%
feature_set2 = df[['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']]
X_train, X_test, y_train, y_test = train_test_split(feature_set, ys.Versicolor, test_size = .3)

# %%
gs = grid_search.GridSearchCV(
    estimator=LogisticRegression(),
    param_grid= {'C': [10**-i for i in range(-5, 5)], 'class_weight': [None, 'balanced']},
    cv=cross_validation.KFold(n=len(X_train), n_folds=10),
    scoring='roc_auc'
)
gs.fit(X_train, y_train)
gs.grid_scores_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-b42a24ce01a6> in <module>()
#       5     scoring='roc_auc'
#       6 )
# ----> 7 gs.fit(X_train, y_train)
#       8 gs.grid_scores_
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/grid_search.pyc in fit(self, X, y)
#     827
#     828         """
# --> 829         return self._fit(X, y, ParameterGrid(self.param_grid))
#     830
#     831
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     571                                     self.fit_params, return_parameters=True,
#     572                                     error_score=self.error_score)
# --> 573                 for parameters in parameter_iterable
#     574                 for train, test in cv)
#     575
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1682
#    1683     else:
# -> 1684         test_score = _score(estimator, X_test, y_test, scorer)
#    1685         if return_train_score:
#    1686             train_score = _score(estimator, X_train, y_train, scorer)
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in _score(estimator, X_test, y_test, scorer)
#    1739         score = scorer(estimator, X_test)
#    1740     else:
# -> 1741         score = scorer(estimator, X_test, y_test)
#    1742     if hasattr(score, 'item'):
#    1743         try:
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.pyc in __call__(self, clf, X, y, sample_weight)
#     194                                                  **self._kwargs)
#     195         else:
# --> 196             return self._sign * self._score_func(y, y_pred, **self._kwargs)
#     197
#     198     def _factory_args(self):
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/metrics/ranking.pyc in roc_auc_score(y_true, y_score, average, sample_weight)
#     258     return _average_binary_score(
#     259         _binary_roc_auc_score, y_true, y_score, average,
# --> 260         sample_weight=sample_weight)
#     261
#     262
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/metrics/base.pyc in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      82
#      83     if y_type == "binary":
# ---> 84         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      85
#      86     check_consistent_length(y_true, y_score, sample_weight)
#
# /Users/jg/anaconda/lib/python2.7/site-packages/sklearn/metrics/ranking.pyc in _binary_roc_auc_score(y_true, y_score, sample_weight)
#     249     def _binary_roc_auc_score(y_true, y_score, sample_weight=None):
#     250         if len(np.unique(y_true)) != 2:
# --> 251             raise ValueError("Only one class present in y_true. ROC AUC score "
#     252                              "is not defined in that case.")
#     253
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
y_pred = gs.best_estimator_.predict(X_test)
confusion_matrix = confusion_matrix(y_test, y_pred)
confusion_matrix
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-f3039ee4e308> in <module>()
#       1 y_pred = gs.best_estimator_.predict(X_test)
# ----> 2 confusion_matrix = confusion_matrix(y_test, y_pred)
#       3 confusion_matrix
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
plt.matshow(confusion_matrix)
plt.title('Confusion matrix')
plt.colorbar()
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show()

# %%
y_pro = gs.best_estimator_.predict_proba(X_test)
fpr = roc_curve(y_test, y_pred)[0]
tpr = roc_curve(y_test, y_pred)[1]
plt.plot(fpr, tpr)

# %%
roc_auc_score(y_test, y_pred)

# %%
y_pro = gs.best_estimator_.predict_proba(X_test)
fpr = roc_curve(y_test, y_pro[:,1])[0]
tpr = roc_curve(y_test, y_pro[:,1])[1]
plt.plot(fpr, tpr)

# %% [markdown]
# ## Model Virginica
